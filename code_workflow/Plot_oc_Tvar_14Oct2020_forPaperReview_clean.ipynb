# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage.filters import gaussian_filter
from confidence_intervals import confidence_envelope

# %% [markdown]
# ## Load the Tvar terms

# %%
datadir = 'Tvar_terms/oc/variance_terms/'
dataname = '_oc_Tvar_'
dataname2 = '_oc_Tvar_23Oct2019_output034_interp2d_'
dataname3 = '_oc_Tvar_slice2_28Nov2019_'
dataname4 = '_oc_Tvar_slice4_28Nov2019_'
dataname5 = '_oc_Tvar_21Apr2020_'


w = np.load('../freq_output_from_code.npy')/365
dw = w[100] - w[99]

# Full-domain ocean Tvar
yrs = '34_133'
vrt_1 = np.load(datadir+'vert_adv'+dataname+yrs+'.npy')
To2_1 = np.load(datadir+'To2'+dataname+yrs+'.npy')
TTa_1 = np.load(datadir+'ToTa'+dataname2+yrs+'.npy')
Tum_1 = np.load(datadir+'Tum'+dataname+yrs+'.npy')
Tvm_1 = np.load(datadir+'Tvm'+dataname+yrs+'.npy')
Fme_1 = np.load(datadir+'Fme'+dataname+yrs+'.npy')
slh_1 = np.load(datadir+'slh'+dataname2+yrs+'.npy')
Td2_1 = np.load(datadir+'Tdel2T'+dataname3+yrs+'.npy')
Td4_1 = np.load(datadir+'Tdel4T'+dataname4+yrs+'.npy')
uEk_1 = np.load(datadir+'Tum_Ek'+dataname5+yrs+'.npy')
vEk_1 = np.load(datadir+'Tvm_Ek'+dataname5+yrs+'.npy')
uge_1 = np.load(datadir+'Tum_geo'+dataname5+yrs+'.npy')
vge_1 = np.load(datadir+'Tvm_geo'+dataname5+yrs+'.npy')


dataname = '_oc_Tvar_28Nov2019_'
dataname2 = '_oc_Tvar_slice2_28Nov2019_'
dataname3 = '_oc_Tvar_slice4_28Nov2019_'
yrs = '84_183'
vrt_2 = np.load(datadir+'vert_adv'+dataname+yrs+'.npy')
To2_2 = np.load(datadir+'To2'+dataname+yrs+'.npy')
TTa_2 = np.load(datadir+'ToTa'+dataname+yrs+'.npy')
Tum_2 = np.load(datadir+'Tum'+dataname+yrs+'.npy')
Tvm_2 = np.load(datadir+'Tvm'+dataname+yrs+'.npy')
Fme_2 = np.load(datadir+'Fme'+dataname+yrs+'.npy')
slh_2 = np.load(datadir+'slh'+dataname+yrs+'.npy')
Td2_2 = np.load(datadir+'Tdel2T'+dataname2+yrs+'.npy')
Td4_2 = np.load(datadir+'Tdel4T'+dataname4+yrs+'.npy')
uEk_2 = np.load(datadir+'Tum_Ek'+dataname5+yrs+'.npy')
vEk_2 = np.load(datadir+'Tvm_Ek'+dataname5+yrs+'.npy')
uge_2 = np.load(datadir+'Tum_geo'+dataname5+yrs+'.npy')
vge_2 = np.load(datadir+'Tvm_geo'+dataname5+yrs+'.npy')

dataname = '_oc_Tvar_23Oct2019_'
dataname2 = '_oc_Tvar_28Nov2019_'
dataname3 = '_oc_Tvar_slice2_28Nov2019_'
dataname4 = '_oc_Tvar_slice4_28Nov2019_'
yrs = '134_233'
vrt_3 = np.load(datadir+'vert_adv'+dataname+yrs+'.npy')
To2_3 = np.load(datadir+'To2'+dataname2+yrs+'.npy')
TTa_3 = np.load(datadir+'ToTa'+dataname2+yrs+'.npy')
Tum_3 = np.load(datadir+'Tum'+dataname2+yrs+'.npy')
Tvm_3 = np.load(datadir+'Tvm'+dataname2+yrs+'.npy')
Fme_3 = np.load(datadir+'Fme'+dataname+yrs+'.npy')
slh_3 = np.load(datadir+'slh'+dataname2+yrs+'.npy')
Td2_3 = np.load(datadir+'Tdel2T'+dataname3+yrs+'.npy')
Td4_3 = np.load(datadir+'Tdel4T'+dataname4+yrs+'.npy')
uEk_3 = np.load(datadir+'Tum_Ek'+dataname5+yrs+'.npy')
vEk_3 = np.load(datadir+'Tvm_Ek'+dataname5+yrs+'.npy')
uge_3 = np.load(datadir+'Tum_geo'+dataname5+yrs+'.npy')
vge_3 = np.load(datadir+'Tvm_geo'+dataname5+yrs+'.npy')

dataname = '_oc_Tvar_21Apr2020_'
yrs = '184_283'
vrt_4 = np.load(datadir+'vert_adv'+dataname+yrs+'.npy')
To2_4 = np.load(datadir+'To2'+dataname+yrs+'.npy')
TTa_4 = np.load(datadir+'ToTa'+dataname+yrs+'.npy')
Tum_4 = np.load(datadir+'Tum'+dataname+yrs+'.npy')
Tvm_4 = np.load(datadir+'Tvm'+dataname+yrs+'.npy')
Fme_4 = np.load(datadir+'Fme'+dataname+yrs+'.npy')
Td2_4 = np.load(datadir+'Tdel2T'+dataname+yrs+'.npy')
Td4_4 = np.load(datadir+'Tdel4T'+dataname+yrs+'.npy')
uEk_4 = np.load(datadir+'Tum_Ek'+dataname5+yrs+'.npy')
vEk_4 = np.load(datadir+'Tvm_Ek'+dataname5+yrs+'.npy')
uge_4 = np.load(datadir+'Tum_geo'+dataname5+yrs+'.npy')
vge_4 = np.load(datadir+'Tvm_geo'+dataname5+yrs+'.npy')

yrs = '234_333'
vrt_5 = np.load(datadir+'vert_adv'+dataname+yrs+'.npy')
To2_5 = np.load(datadir+'To2'+dataname+yrs+'.npy')
TTa_5 = np.load(datadir+'ToTa'+dataname+yrs+'.npy')
Tum_5 = np.load(datadir+'Tum'+dataname+yrs+'.npy')
Tvm_5 = np.load(datadir+'Tvm'+dataname+yrs+'.npy')
Fme_5 = np.load(datadir+'Fme'+dataname+yrs+'.npy')
Td2_5 = np.load(datadir+'Tdel2T'+dataname+yrs+'.npy')
Td4_5 = np.load(datadir+'Tdel4T'+dataname+yrs+'.npy')
uEk_5 = np.load(datadir+'Tum_Ek'+dataname5+yrs+'.npy')
vEk_5 = np.load(datadir+'Tvm_Ek'+dataname5+yrs+'.npy')
uge_5 = np.load(datadir+'Tum_geo'+dataname5+yrs+'.npy')
vge_5 = np.load(datadir+'Tvm_geo'+dataname5+yrs+'.npy')

yrs = '284_383'
vrt_6 = np.load(datadir+'vert_adv'+dataname+yrs+'.npy')
To2_6 = np.load(datadir+'To2'+dataname+yrs+'.npy')
TTa_6 = np.load(datadir+'ToTa'+dataname+yrs+'.npy')
Tum_6 = np.load(datadir+'Tum'+dataname+yrs+'.npy')
Tvm_6 = np.load(datadir+'Tvm'+dataname+yrs+'.npy')
Fme_6 = np.load(datadir+'Fme'+dataname+yrs+'.npy')
Td2_6 = np.load(datadir+'Tdel2T'+dataname+yrs+'.npy')
Td4_6 = np.load(datadir+'Tdel4T'+dataname+yrs+'.npy')
uEk_6 = np.load(datadir+'Tum_Ek'+dataname5+yrs+'.npy')
vEk_6 = np.load(datadir+'Tvm_Ek'+dataname5+yrs+'.npy')
uge_6 = np.load(datadir+'Tum_geo'+dataname5+yrs+'.npy')
vge_6 = np.load(datadir+'Tvm_geo'+dataname5+yrs+'.npy')

yrs = '334_433'
vrt_7 = np.load(datadir+'vert_adv'+dataname+yrs+'.npy')
To2_7 = np.load(datadir+'To2'+dataname+yrs+'.npy')
TTa_7 = np.load(datadir+'ToTa'+dataname+yrs+'.npy')
Tum_7 = np.load(datadir+'Tum'+dataname+yrs+'.npy')
Tvm_7 = np.load(datadir+'Tvm'+dataname+yrs+'.npy')
Fme_7 = np.load(datadir+'Fme'+dataname+yrs+'.npy')
Td2_7 = np.load(datadir+'Tdel2T'+dataname+yrs+'.npy')
Td4_7 = np.load(datadir+'Tdel4T'+dataname+yrs+'.npy')
uEk_7 = np.load(datadir+'Tum_Ek'+dataname5+yrs+'.npy')
vEk_7 = np.load(datadir+'Tvm_Ek'+dataname5+yrs+'.npy')
uge_7 = np.load(datadir+'Tum_geo'+dataname5+yrs+'.npy')
vge_7 = np.load(datadir+'Tvm_geo'+dataname5+yrs+'.npy')

# %%
vrt_avg = np.mean((vrt_1,vrt_2,vrt_3,vrt_4,vrt_5,vrt_6,vrt_7),axis=0)
To2_avg = np.mean((To2_1,To2_2,To2_3,To2_4,To2_5,To2_6,To2_7),axis=0)
TTa_avg = np.mean((TTa_1,TTa_2,TTa_3,TTa_4,TTa_5,TTa_6,TTa_7),axis=0)
Tum_avg = np.mean((Tum_1,Tum_2,Tum_3,Tum_4,Tum_5,Tum_6,Tum_7),axis=0)
Tvm_avg = np.mean((Tvm_1,Tvm_2,Tvm_3,Tvm_4,Tvm_5,Tvm_6,Tvm_7),axis=0)
Fme_avg = np.mean((Fme_1,Fme_2,Fme_3,Fme_4,Fme_5,Fme_6,Fme_7),axis=0)
Td2_avg = np.mean((Td2_1,Td2_2,Td2_3,Td2_4,Td2_5,Td2_6,Td2_7),axis=0)
Td4_avg = np.mean((Td4_1,Td4_2,Td4_3,Td4_4,Td4_5,Td4_6,Td4_7),axis=0)
uEk_avg = np.mean((uEk_1,uEk_2,uEk_3,uEk_4,uEk_5,uEk_6,uEk_7),axis=0)
vEk_avg = np.mean((vEk_1,vEk_2,vEk_3,vEk_4,vEk_5,vEk_6,vEk_7),axis=0)
uge_avg = np.mean((uge_1,uge_2,uge_3,uge_4,uge_5,uge_6,uge_7),axis=0)
vge_avg = np.mean((vge_1,vge_2,vge_3,vge_4,vge_5,vge_6,vge_7),axis=0)

# %% [markdown]
# np.save('Tum_geo_7x100yrAVG_oc_Tvar_21Apr2020_34_433.npy',uge_avg)
# np.save('Tvm_geo_7x100yrAVG_oc_Tvar_21Apr2020_34_433.npy',vge_avg)
# np.save('Tum_Ek_7x100yrAVG_oc_Tvar_21Apr2020_34_433.npy',uEk_avg)
# np.save('Tvm_Ek_7x100yrAVG_oc_Tvar_21Apr2020_34_433.npy',vEk_avg)

# %% [markdown]
# # Load PC variance data

# %%
datadir = 'Tvar_terms/oc/variance_terms/'
dataname = '_oc_ycexp_21Apr2020_'
dataname2 = '_oc_ycexp_28Nov2019_'


# Full-domain ocean Tvar
yrs = '233_332'
vrt_1y = np.load(datadir+'vert_adv'+dataname2+yrs+'.npy')
To2_1y = np.load(datadir+'To2'+dataname+yrs+'.npy')
TTa_1y = np.load(datadir+'ToTa'+dataname+yrs+'.npy')
Tum_1y = np.load(datadir+'Tum'+dataname+yrs+'.npy')
Tvm_1y = np.load(datadir+'Tvm'+dataname+yrs+'.npy')
Fme_1y = np.load(datadir+'Fme'+dataname+yrs+'.npy')
Td2_1y = np.load(datadir+'Tdel2T'+dataname+yrs+'.npy')
Td4_1y = np.load(datadir+'Tdel4T'+dataname2+yrs+'.npy')

yrs = '283_382'
vrt_2y = np.load(datadir+'vert_adv'+dataname+yrs+'.npy')
To2_2y = np.load(datadir+'To2'+dataname+yrs+'.npy')
TTa_2y = np.load(datadir+'ToTa'+dataname+yrs+'.npy')
Tum_2y = np.load(datadir+'Tum'+dataname+yrs+'.npy')
Tvm_2y = np.load(datadir+'Tvm'+dataname+yrs+'.npy')
Fme_2y = np.load(datadir+'Fme'+dataname+yrs+'.npy')
Td2_2y = np.load(datadir+'Tdel2T'+dataname+yrs+'.npy')
Td4_2y = np.load(datadir+'Tdel4T'+dataname+yrs+'.npy')

yrs = '333_432'
vrt_3y = np.load(datadir+'vert_adv'+dataname+yrs+'.npy')
To2_3y = np.load(datadir+'To2'+dataname+yrs+'.npy')
TTa_3y = np.load(datadir+'ToTa'+dataname+yrs+'.npy')
Tum_3y = np.load(datadir+'Tum'+dataname+yrs+'.npy')
Tvm_3y = np.load(datadir+'Tvm'+dataname+yrs+'.npy')
Fme_3y = np.load(datadir+'Fme'+dataname+yrs+'.npy')
Td2_3y = np.load(datadir+'Tdel2T'+dataname+yrs+'.npy')
Td4_3y = np.load(datadir+'Tdel4T'+dataname+yrs+'.npy')

yrs = '383_482'
vrt_4y = np.load(datadir+'vert_adv'+dataname+yrs+'.npy')
To2_4y = np.load(datadir+'To2'+dataname+yrs+'.npy')
TTa_4y = np.load(datadir+'ToTa'+dataname+yrs+'.npy')
Tum_4y = np.load(datadir+'Tum'+dataname+yrs+'.npy')
Tvm_4y = np.load(datadir+'Tvm'+dataname+yrs+'.npy')
Fme_4y = np.load(datadir+'Fme'+dataname+yrs+'.npy')
Td2_4y = np.load(datadir+'Tdel2T'+dataname+yrs+'.npy')
Td4_4y = np.load(datadir+'Tdel4T'+dataname+yrs+'.npy')

yrs = '433_532'
vrt_5y = np.load(datadir+'vert_adv'+dataname+yrs+'.npy')
To2_5y = np.load(datadir+'To2'+dataname+yrs+'.npy')
TTa_5y = np.load(datadir+'ToTa'+dataname+yrs+'.npy')
Tum_5y = np.load(datadir+'Tum'+dataname+yrs+'.npy')
Tvm_5y = np.load(datadir+'Tvm'+dataname+yrs+'.npy')
Fme_5y = np.load(datadir+'Fme'+dataname+yrs+'.npy')
Td2_5y = np.load(datadir+'Tdel2T'+dataname+yrs+'.npy')
Td4_5y = np.load(datadir+'Tdel4T'+dataname+yrs+'.npy')

yrs = '483_582'
vrt_6y = np.load(datadir+'vert_adv'+dataname+yrs+'.npy')
To2_6y = np.load(datadir+'To2'+dataname+yrs+'.npy')
TTa_6y = np.load(datadir+'ToTa'+dataname+yrs+'.npy')
Tum_6y = np.load(datadir+'Tum'+dataname+yrs+'.npy')
Tvm_6y = np.load(datadir+'Tvm'+dataname+yrs+'.npy')
Fme_6y = np.load(datadir+'Fme'+dataname+yrs+'.npy')
Td2_6y = np.load(datadir+'Tdel2T'+dataname+yrs+'.npy')
Td4_6y = np.load(datadir+'Tdel4T'+dataname+yrs+'.npy')

yrs = '533_632'
vrt_7y = np.load(datadir+'vert_adv'+dataname+yrs+'.npy')
To2_7y = np.load(datadir+'To2'+dataname+yrs+'.npy')
TTa_7y = np.load(datadir+'ToTa'+dataname+yrs+'.npy')
Tum_7y = np.load(datadir+'Tum'+dataname+yrs+'.npy')
Tvm_7y = np.load(datadir+'Tvm'+dataname+yrs+'.npy')
Fme_7y = np.load(datadir+'Fme'+dataname+yrs+'.npy')
Td2_7y = np.load(datadir+'Tdel2T'+dataname+yrs+'.npy')
Td4_7y = np.load(datadir+'Tdel4T'+dataname+yrs+'.npy')

# %%
vrt_avgy = np.mean((vrt_1y,vrt_2y,vrt_3y,vrt_4y,vrt_5y,vrt_6y,vrt_7y),axis=0)
To2_avgy = np.mean((To2_1y,To2_2y,To2_3y,To2_4y,To2_5y,To2_6y,To2_7y),axis=0)
TTa_avgy = np.mean((TTa_1y,TTa_2y,TTa_3y,TTa_4y,TTa_5y,TTa_6y,TTa_7y),axis=0)
Tum_avgy = np.mean((Tum_1y,Tum_2y,Tum_3y,Tum_4y,Tum_5y,Tum_6y,Tum_7y),axis=0)
Tvm_avgy = np.mean((Tvm_1y,Tvm_2y,Tvm_3y,Tvm_4y,Tvm_5y,Tvm_6y,Tvm_7y),axis=0)
Fme_avgy = np.mean((Fme_1y,Fme_2y,Fme_3y,Fme_4y,Fme_5y,Fme_6y,Fme_7y),axis=0)
Td2_avgy = np.mean((Td2_1y,Td2_2y,Td2_3y,Td2_4y,Td2_5y,Td2_6y,Td2_7y),axis=0)
Td4_avgy = np.mean((Td4_1y,Td4_2y,Td4_3y,Td4_4y,Td4_5y,Td4_6y,Td4_7y),axis=0)

# %%
print(dataname,datadir)
# Out:
# _oc_ycexp_21Apr2020_ Tvar_terms/oc/variance_terms/

# %% [markdown]
# vrt_avg = np.mean((vrt_1,vrt_2,vrt_3),axis=0) #,vrt_4,vrt_5,vrt_6,vrt_7),axis=0)
# To2_avg = np.mean((To2_1,To2_2,To2_3),axis=0) #,To2_4,To2_5,To2_6,To2_7),axis=0)
# TTa_avg = np.mean((TTa_1,TTa_2,TTa_3),axis=0)
# Tum_avg = np.mean((Tum_1,Tum_2,Tum_3),axis=0) #,Tum_4,Tum_5,Tum_6,Tum_7),axis=0)
# Tvm_avg = np.mean((Tvm_1,Tvm_2,Tvm_3),axis=0) #,Tvm_4,Tvm_5,Tvm_6,Tvm_7),axis=0)
# Fme_avg = np.mean((Fme_1,Fme_2,Fme_3),axis=0) #,Fme_4,Fme_5,Fme_6,Fme_7),axis=0)
# Td2_avg = np.mean((Td2_1,Td2_2,Td2_3),axis=0) #,Td2_4,Td2_5,Td2_6,Td2_7),axis=0)
# Td4_avg = np.mean((Td4_1,Td4_2,Td4_3),axis=0)

# %% [markdown]
# np.save(datadir+'vert_adv_7x100yrAVG'+dataname+'34_433'+'.npy',vrt_avg)
# np.save(datadir+'Tum_7x100yrAVG'+dataname+'34_433'+'.npy',Tum_avg)
# np.save(datadir+'Tvm_7x100yrAVG'+dataname+'34_433'+'.npy',Tvm_avg)
# np.save(datadir+'Tdel2T_7x100yrAVG'+dataname+'34_433'+'.npy',Td2_avg)
# np.save(datadir+'Tdel4T_7x100yrAVG'+dataname+'34_433'+'.npy',Td4_avg)
# np.save(datadir+'To2_7x100yrAVG'+dataname+'34_433'+'.npy',To2_avg)
# np.save(datadir+'ToTa_7x100yrAVG'+dataname+'34_433'+'.npy',TTa_avg)
# np.save(datadir+'Fme_7x100yrAVG'+dataname+'34_433'+'.npy',Fme_avg)

# %% [markdown]
# np.save(datadir+'vert_adv_7x100yrAVG'+dataname+'233_632'+'.npy',vrt_avgy)
# np.save(datadir+'Tum_7x100yrAVG'+dataname+'233_632'+'.npy',Tum_avgy)
# np.save(datadir+'Tvm_7x100yrAVG'+dataname+'233_632'+'.npy',Tvm_avgy)
# np.save(datadir+'Tdel2T_7x100yrAVG'+dataname+'233_632'+'.npy',Td2_avgy)
# np.save(datadir+'Tdel4T_7x100yrAVG'+dataname+'233_632'+'.npy',Td4_avgy)
# np.save(datadir+'To2_7x100yrAVG'+dataname+'233_632'+'.npy',To2_avgy)
# np.save(datadir+'ToTa_7x100yrAVG'+dataname+'233_632'+'.npy',TTa_avgy)
# np.save(datadir+'Fme_7x100yrAVG'+dataname+'233_632'+'.npy',Fme_avgy)

# %% [markdown]
# # Define constants

# %%
dx = 5000. # meters
dy = 5000. # meters
#dt = 1 # in days
H = [350.0, 750.0, 2900.0]  # meters
Htot = H[0] + H[1] + H[2]
Hm = 100 # meters (mixed layer height)
f0 = 9.37456*(10**(-5)) #1/s (Coriolis parameter)
g = [.015, .0075]
delta_ek = 2. # meters
alpha_bc = 0.2 # nondimensional mixed boundary condition for OCEAN
gamma = 0.5*alpha_bc + 1 # nondimensional number for ease of calculation
rho = 1000.0 # kg/(m^3)
Cp = 4000. # specific heat of ocean in J/(kg*K)
T1 = 287
ocnorm = 1.0/(960*960) #from QGCM write-up
dt = 86400.0 # seconds in a day (time difference between each point in time)
K2 = 200 # m^2/s (called st2d in input.params)
K4 = 2e9 # m^4/s (called st4d in input.params)
tmbaro = 3.04870e2 # mean ocean mixed layer absolute temperature (K)
tmbara = 3.05522e2 # mean atmosphere mixed layer absolute temperature (K)
toc1 = -1.78699e1 # Relative temperature for ocean layer 1

mask = 2 # number of cells to mask at boundaries

# --------------------------------
# The following are radiation constants output from the model
Dmdown = -3.2342349507402 
D0up = 6.4271329356690 
lamda = 35.00000 # sensible/latent heat flux coefficient (W m^2/kg) 
Fs_prime = 80.0 # perturbation amplitude of incoming solar radiation (W/m^2)

# %% [markdown]
# # Multiply terms by the appropriate constants

# %%
def mult_const(Tum,Tvm,vert_adv,slh,To2,ToTa,Fme,Tdel2T,Tdel4T):

    Tum_plot = -Tum * ocnorm * 2
    Tvm_plot = -Tvm * ocnorm * 2
    
    vert_adv_plot = vert_adv * ocnorm * 2
    
    slh_plot = -(lamda/(rho*Cp*Hm)) * (To2 - ToTa) * ocnorm * 2
    
    oc_rh = -(D0up/(rho*Cp*Hm)) * To2 * ocnorm * 2
    
    atm_rh = -(Dmdown/(rho*Cp*Hm)) * ToTa * ocnorm * 2
    
    Fme_plot = -0.5 * (1/Hm) * (Fme) * ocnorm * 2
    
    Tdel2T_plot = K2 * Tdel2T * ocnorm * 2
    
    Tdel4T_plot = - K4 * Tdel4T * ocnorm * 2
    
    sum_terms = np.sum((Tum_plot,Tvm_plot,slh_plot,oc_rh,atm_rh,vert_adv_plot,Fme_plot,Tdel2T_plot,Tdel4T_plot),axis=0)
    
    return Tum_plot,Tvm_plot,vert_adv_plot,slh_plot,oc_rh,atm_rh,Fme_plot,Tdel2T_plot,Tdel4T_plot,sum_terms

##sum_terms = np.sum((Tum_plot,Tvm_plot,slh_plot,oc_rh,atm_rh,vert_adv_plot,Fme_plot),axis=0)
#print(sum_terms.shape)
#
## Second 100 yeras
#vert_adv2_plot = vert_adv2 * ocnorm
#
#oc_rh2 = -(D0up/(rho*Cp*Hm)) * To22 * ocnorm
#
#Fme2_plot = -0.5 * (1/Hm) * (Fme2) * ocnorm

# %% [markdown]
# ## Function to plot lines/labels

# %%
def plot_lines():
    plt.axhline(0,color='k',linestyle='dotted')
    #plt.axvline((1./20),color='k',linestyle='dotted')
    plt.axvline((1./30),color='k',linestyle='dotted')
    plt.axvline((1./90),color='k',linestyle='dotted')
    plt.axvline((1./(365)),color='k',linestyle='dotted')
    plt.axvline((1./(10*365)),color='k',linestyle='dotted')
    #plt.axvline((1./(17*365)),color='k',linestyle='dotted')
    #plt.axvline((1./(34*365)),color='k',linestyle='dotted')
    #plt.text(1./(20+3),vtext_loc,'20 days',rotation=90,fontsize=20)
    plt.text(1./(30+5),vtext_loc,' 30 days',rotation=90,fontsize=20)
    plt.text(1./(90+20),vtext_loc,' 90 days',rotation=90,fontsize=20)
    plt.text(1./(430),vtext_loc,'   1 year',rotation=90,fontsize=20)
    plt.text(1./(10*365+600),vtext_loc,'10 years',rotation=90,fontsize=20)
    #plt.text(1./(17*365+1000),vtext_loc,'17 years',rotation=90,fontsize=20)
    #plt.text(1./(34*365+2200),vtext_loc,'34 years',rotation=90,fontsize=20)
    
    plt.axhline(0,color='k',linestyle='dotted')
    plt.legend(fontsize=18,loc='upper right')
    plt.xlabel('Frequency (cycles/day)',fontsize=22)
    plt.ylabel('(K$^2$/s)/(cycles/day)',fontsize=22)
    plt.xticks(fontsize=18)
    plt.yticks(fontsize=18)
    plt.title('Ocean Spectral temperature variance terms',fontsize=30)
    plt.xlim(w[1],w[-1])

# %% [markdown]
# # Plot above plot with colors from published paper

# %%
# New colors (also taken from colorblind palatte)
KEcolor = '#267FE3'
PEcolor = '#FF336C'
Botcolor = '#3DBF19'
Buoycolor = '#B65AFE'
Windcolor = '#FFA433'
Rescolor = 'grey'

# %% [markdown]
# # Plot FC and PC in same figure

# %% [markdown]
# # Confidence intervals for PC

# %%
def mult_const(Tum,Tvm,vert_adv,To2,ToTa,Fme,Tdel2T,Tdel4T):

    Tum_plot = -Tum * ocnorm * 2
    Tvm_plot = -Tvm * ocnorm * 2
    
    vert_adv_plot = vert_adv * ocnorm * 2
    
    slh_plot = -(lamda/(rho*Cp*Hm)) * (To2 - ToTa) * ocnorm * 2
    
    oc_rh = -(D0up/(rho*Cp*Hm)) * To2 * ocnorm * 2
    
    atm_rh = -(Dmdown/(rho*Cp*Hm)) * ToTa * ocnorm * 2
    
    Fme_plot = -0.5 * (1/Hm) * (Fme) * ocnorm * 2
    
    Tdel2T_plot = K2 * Tdel2T * ocnorm * 2
    
    Tdel4T_plot = - K4 * Tdel4T * ocnorm * 2
    
    sum_terms = np.sum((Tum_plot,Tvm_plot,slh_plot,oc_rh,atm_rh,vert_adv_plot,Fme_plot,Tdel2T_plot,Tdel4T_plot),axis=0)
    
    return Tum_plot,Tvm_plot,vert_adv_plot,slh_plot,oc_rh,atm_rh,Fme_plot,Tdel2T_plot,Tdel4T_plot,sum_terms

# %% [markdown]
# ### PC

# %%
Tum1,Tvm1,vrt1,slh1,och1,ath1,Fme1,Td21,Td41,sum_terms1 = mult_const(Tum_1y,Tvm_1y,vrt_1y,To2_1y,TTa_1y,Fme_1y,Td2_1y,Td4_1y)
Tum2,Tvm2,vrt2,slh2,och2,ath2,Fme2,Td22,Td42,sum_terms2 = mult_const(Tum_2y,Tvm_2y,vrt_2y,To2_2y,TTa_2y,Fme_2y,Td2_2y,Td4_2y)
Tum3,Tvm3,vrt3,slh3,och3,ath3,Fme3,Td23,Td43,sum_terms3 = mult_const(Tum_3y,Tvm_3y,vrt_3y,To2_3y,TTa_3y,Fme_3y,Td2_3y,Td4_3y)
Tum4,Tvm4,vrt4,slh4,och4,ath4,Fme4,Td24,Td44,sum_terms4 = mult_const(Tum_4y,Tvm_4y,vrt_4y,To2_4y,TTa_4y,Fme_4y,Td2_4y,Td4_4y)
Tum5,Tvm5,vrt5,slh5,och5,ath5,Fme5,Td25,Td45,sum_terms5 = mult_const(Tum_5y,Tvm_5y,vrt_5y,To2_5y,TTa_5y,Fme_5y,Td2_5y,Td4_5y)
Tum6,Tvm6,vrt6,slh6,och6,ath6,Fme6,Td26,Td46,sum_terms6 = mult_const(Tum_6y,Tvm_6y,vrt_6y,To2_6y,TTa_6y,Fme_6y,Td2_6y,Td4_6y)
Tum7,Tvm7,vrt7,slh7,och7,ath7,Fme7,Td27,Td47,sum_terms7 = mult_const(Tum_7y,Tvm_7y,vrt_7y,To2_7y,TTa_7y,Fme_7y,Td2_7y,Td4_7y)

# %%
vrt_avgy = np.mean((vrt1+Fme1,vrt2+Fme2,vrt3+Fme3,vrt4+Fme4,vrt5+Fme5,vrt6+Fme6,vrt7+Fme7),axis=0)
rah_avgy = np.mean((och1+ath1,och2+ath2,och3+ath3,och4+ath4,och5+ath5,och6+ath6,och7+ath7),axis=0)
slh_avgy = np.mean((slh1,slh2,slh3,slh4,slh5,slh6,slh7),axis=0)
Tde_avgy = np.mean((Td21+Td41,Td22+Td42,Td23+Td43,Td24+Td44,Td25+Td45,Td26+Td46,Td27+Td47),axis=0)
Had_avgy = np.mean((Tum1+Tvm1,Tum2+Tvm2,Tum3+Tvm3,Tum4+Tvm4,Tum5+Tvm5,Tum6+Tvm6,Tum7+Tvm7),axis=0)
sum_avgy = np.mean((sum_terms1,sum_terms2,sum_terms3,sum_terms4,sum_terms5,sum_terms6,sum_terms7),axis=0)
vta_avgy = np.mean((vrt1,vrt2,vrt3,vrt4,vrt5,vrt6,vrt7),axis=0)
Fme_avgy = np.mean((Fme1,Fme2,Fme3,Fme4,Fme5,Fme6,Fme7),axis=0)

vrt_stack = np.vstack((vrt1+Fme1,vrt2+Fme2,vrt3+Fme3,vrt4+Fme4,vrt5+Fme5,vrt6+Fme6,vrt7+Fme7))
rah_stack = np.vstack((och1+ath1,och2+ath2,och3+ath3,och4+ath4,och5+ath5,och6+ath6,och7+ath7))
slh_stack = np.vstack((slh1,slh2,slh3,slh4,slh5,slh6,slh7))
Tde_stack = np.vstack((Td21+Td41,Td22+Td42,Td23+Td43,Td24+Td44,Td25+Td45,Td26+Td46,Td27+Td47))
Had_stack = np.vstack((Tum1+Tvm1,Tum2+Tvm2,Tum3+Tvm3,Tum4+Tvm4,Tum5+Tvm5,Tum6+Tvm6,Tum7+Tvm7))
vta_stack = np.vstack((vrt1,vrt2,vrt3,vrt4,vrt5,vrt6,vrt7))
Fme_stack = np.vstack((Fme1,Fme2,Fme3,Fme4,Fme5,Fme6,Fme7))
sum_stack = np.vstack((sum_terms1,sum_terms2,sum_terms3,sum_terms4,sum_terms5,sum_terms6,sum_terms7))

vrt_stdy = np.std(vrt_stack,axis=0) 
rah_stdy = np.std(rah_stack,axis=0) 
slh_stdy = np.std(slh_stack,axis=0) 
Tde_stdy = np.std(Tde_stack,axis=0) 
Had_stdy = np.std(Had_stack,axis=0)
vta_stdy = np.std(vta_stack,axis=0) 
Fme_stdy = np.std(Fme_stack,axis=0)
sum_stdy = np.std(sum_stack,axis=0)

# %% [markdown]
# ### FC

# %%
Tum1,Tvm1,vrt1,slh1,och1,ath1,Fme1,Td21,Td41,sum_terms1 = mult_const(Tum_1,Tvm_1,vrt_1,To2_1,TTa_1,Fme_1,Td2_1,Td4_1)
Tum2,Tvm2,vrt2,slh2,och2,ath2,Fme2,Td22,Td42,sum_terms2 = mult_const(Tum_2,Tvm_2,vrt_2,To2_2,TTa_2,Fme_2,Td2_2,Td4_2)
Tum3,Tvm3,vrt3,slh3,och3,ath3,Fme3,Td23,Td43,sum_terms3 = mult_const(Tum_3,Tvm_3,vrt_3,To2_3,TTa_3,Fme_3,Td2_3,Td4_3)
Tum4,Tvm4,vrt4,slh4,och4,ath4,Fme4,Td24,Td44,sum_terms4 = mult_const(Tum_4,Tvm_4,vrt_4,To2_4,TTa_4,Fme_4,Td2_4,Td4_4)
Tum5,Tvm5,vrt5,slh5,och5,ath5,Fme5,Td25,Td45,sum_terms5 = mult_const(Tum_5,Tvm_5,vrt_5,To2_5,TTa_5,Fme_5,Td2_5,Td4_5)
Tum6,Tvm6,vrt6,slh6,och6,ath6,Fme6,Td26,Td46,sum_terms6 = mult_const(Tum_6,Tvm_6,vrt_6,To2_6,TTa_6,Fme_6,Td2_6,Td4_6)
Tum7,Tvm7,vrt7,slh7,och7,ath7,Fme7,Td27,Td47,sum_terms7 = mult_const(Tum_7,Tvm_7,vrt_7,To2_7,TTa_7,Fme_7,Td2_7,Td4_7)

# %%
vrt_avg = np.mean((vrt1+Fme1,vrt2+Fme2,vrt3+Fme3,vrt4+Fme4,vrt5+Fme5,vrt6+Fme6,vrt7+Fme7),axis=0)
rah_avg = np.mean((och1+ath1,och2+ath2,och3+ath3,och4+ath4,och5+ath5,och6+ath6,och7+ath7),axis=0)
slh_avg = np.mean((slh1,slh2,slh3,slh4,slh5,slh6,slh7),axis=0)
Tde_avg = np.mean((Td21+Td41,Td22+Td42,Td23+Td43,Td24+Td44,Td25+Td45,Td26+Td46,Td27+Td47),axis=0)
Had_avg = np.mean((Tum1+Tvm1,Tum2+Tvm2,Tum3+Tvm3,Tum4+Tvm4,Tum5+Tvm5,Tum6+Tvm6,Tum7+Tvm7),axis=0)
sum_avg = np.mean((sum_terms1,sum_terms2,sum_terms3,sum_terms4,sum_terms5,sum_terms6,sum_terms7),axis=0)
vta_avg = np.mean((vrt1,vrt2,vrt3,vrt4,vrt5,vrt6,vrt7),axis=0)
Fme_avg = np.mean((Fme1,Fme2,Fme3,Fme4,Fme5,Fme6,Fme7),axis=0)

vrt_stack = np.vstack((vrt1+Fme1,vrt2+Fme2,vrt3+Fme3,vrt4+Fme4,vrt5+Fme5,vrt6+Fme6,vrt7+Fme7))
rah_stack = np.vstack((och1+ath1,och2+ath2,och3+ath3,och4+ath4,och5+ath5,och6+ath6,och7+ath7))
slh_stack = np.vstack((slh1,slh2,slh3,slh4,slh5,slh6,slh7))
Tde_stack = np.vstack((Td21+Td41,Td22+Td42,Td23+Td43,Td24+Td44,Td25+Td45,Td26+Td46,Td27+Td47))
Had_stack = np.vstack((Tum1+Tvm1,Tum2+Tvm2,Tum3+Tvm3,Tum4+Tvm4,Tum5+Tvm5,Tum6+Tvm6,Tum7+Tvm7))
vta_stack = np.vstack((vrt1,vrt2,vrt3,vrt4,vrt5,vrt6,vrt7))
Fme_stack = np.vstack((Fme1,Fme2,Fme3,Fme4,Fme5,Fme6,Fme7))
sum_stack = np.vstack((sum_terms1,sum_terms2,sum_terms3,sum_terms4,sum_terms5,sum_terms6,sum_terms7))

vrt_std = np.std(vrt_stack,axis=0) 
rah_std = np.std(rah_stack,axis=0) 
slh_std = np.std(slh_stack,axis=0) 
Tde_std = np.std(Tde_stack,axis=0) 
Had_std = np.std(Had_stack,axis=0)
vta_std = np.std(vta_stack,axis=0) 
Fme_std = np.std(Fme_stack,axis=0)
sum_std = np.std(sum_stack,axis=0)

# %%
vtext_loc = -2*2.8e-6 # For vertical line labeling
ymin = 0
ymax = 0
n_std = np.sqrt(7)
conf_interval = 95

avg_percents=np.array((.12,.2,.5,.5,38.68,60))
avg_nums=np.array((1,3,9,15,21,51))

plt.figure(figsize=(18,20))
plt.subplot(211)

avgdT,avgdT_w,min_lineT,max_lineT,bin_length = confidence_envelope(conf_interval,w,(Tde_avg),(Tde_std),n_std,avg_nums,avg_percents)
plt.semilogx(avgdT_w[1:],avgdT[1:]/dw,color='k',label='Diffusion')
plt.fill_between(avgdT_w,min_lineT/dw,max_lineT/dw,color='k',alpha=0.3)

avgds,avgds_w,min_lines,max_lines,bin_length = confidence_envelope(conf_interval,w,sum_avg,sum_std,n_std,avg_nums,avg_percents)
plt.semilogx(avgds_w[1:],avgds[1:]/dw,color='grey',label='Residual')
plt.fill_between(avgds_w,min_lines/dw,max_lines/dw,color='grey',alpha=0.3)

avgd1,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,(Had_avg),(Had_std),n_std,avg_nums,avg_percents)
plt.semilogx(avgd1_w[1:],avgd1[1:]/dw,color=KEcolor,label='Horizontal advection')
plt.fill_between(avgd1_w,min_line1/dw,max_line1/dw,color=KEcolor,alpha=0.3)

avgd2,avgd2_w,min_line2,max_line2,bin_length = confidence_envelope(conf_interval,w,(Fme_avg),(vrt_std),n_std,avg_nums,avg_percents)
plt.semilogx(avgd2_w[1:],avgd2[1:]/dw,color=PEcolor,label='Entrainment heat flux')
plt.fill_between(avgd2_w,min_line2/dw,max_line2/dw,color=PEcolor,alpha=0.3)

avgd2,avgd2_w,min_line2,max_line2,bin_length = confidence_envelope(conf_interval,w,(vta_avg),(vta_std),n_std,avg_nums,avg_percents)
plt.semilogx(avgd2_w[1:],avgd2[1:]/dw,color='c',label='Vertical advection')
plt.fill_between(avgd2_w,min_line2/dw,max_line2/dw,color='c',alpha=0.3)

avgdo,avgdo_w,min_lineo,max_lineo,bin_length = confidence_envelope(conf_interval,w,slh_avg,slh_std,n_std,avg_nums,avg_percents)
plt.semilogx(avgdo_w[1:],avgdo[1:]/dw,color=Buoycolor,label='Sensible/latent heat')
plt.fill_between(avgdo_w,min_lineo/dw,max_lineo/dw,color=Buoycolor,alpha=0.3)

avgda,avgda_w,min_linea,max_linea,bin_length = confidence_envelope(conf_interval,w,rah_avg,rah_std,n_std,avg_nums,avg_percents)
plt.semilogx(avgda_w[1:],avgda[1:]/dw,color=Windcolor,label='Radiative heat')
plt.fill_between(avgda_w,min_linea/dw,max_linea/dw,color=Windcolor,alpha=0.3)

plot_lines()
plt.axvline(avgds_w[14])
plt.legend(fontsize=18)
plt.title('(a) FC',fontsize=32)
plt.xlabel('')

plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0),useMathText=True)
plt.gca().yaxis.get_offset_text().set_fontsize(18)

plt.subplot(212)

vtext_loc = -2*8.5e-6 # For vertical line labeling

avgdT,avgdT_w,min_lineT,max_lineT,bin_length = confidence_envelope(conf_interval,w,(Tde_avgy),(Tde_stdy),n_std,avg_nums,avg_percents)
plt.semilogx(avgdT_w[1:],avgdT[1:]/dw,color='k',label='Diffusion')
plt.fill_between(avgdT_w,min_lineT/dw,max_lineT/dw,color='k',alpha=0.3)

avgds,avgds_w,min_lines,max_lines,bin_length = confidence_envelope(conf_interval,w,sum_avgy,sum_stdy,n_std,avg_nums,avg_percents)
plt.semilogx(avgds_w[1:],avgds[1:]/dw,color='grey',label='Residual')
plt.fill_between(avgds_w,min_lines/dw,max_lines/dw,color='grey',alpha=0.3)

avgd1,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,(Had_avgy),(Had_stdy),n_std,avg_nums,avg_percents)
plt.semilogx(avgd1_w[1:],avgd1[1:]/dw,color=KEcolor,label='Horizontal advection')
plt.fill_between(avgd1_w,min_line1/dw,max_line1/dw,color=KEcolor,alpha=0.3)

avgd2,avgd2_w,min_line2,max_line2,bin_length = confidence_envelope(conf_interval,w,(Fme_avgy),(Fme_stdy),n_std,avg_nums,avg_percents)
plt.semilogx(avgd2_w[1:],avgd2[1:]/dw,color=PEcolor,label='Entrainment heat flux')
plt.fill_between(avgd2_w,min_line2/dw,max_line2/dw,color=PEcolor,alpha=0.3)

avgd2,avgd2_w,min_line2,max_line2,bin_length = confidence_envelope(conf_interval,w,(vta_avgy),(vta_stdy),n_std,avg_nums,avg_percents)
plt.semilogx(avgd2_w[1:],avgd2[1:]/dw,color='c',label='Vertical advection')
plt.fill_between(avgd2_w,min_line2/dw,max_line2/dw,color='c',alpha=0.3)

avgdo,avgdo_w,min_lineo,max_lineo,bin_length = confidence_envelope(conf_interval,w,slh_avgy,slh_stdy,n_std,avg_nums,avg_percents)
plt.semilogx(avgdo_w[1:],avgdo[1:]/dw,color=Buoycolor,label='Sensible/latent heat')
plt.fill_between(avgdo_w,min_lineo/dw,max_lineo/dw,color=Buoycolor,alpha=0.3)

avgda,avgda_w,min_linea,max_linea,bin_length = confidence_envelope(conf_interval,w,rah_avgy,rah_stdy,n_std,avg_nums,avg_percents)
plt.semilogx(avgda_w[1:],avgda[1:]/dw,color=Windcolor,label='Radiative heat')
plt.fill_between(avgda_w,min_linea/dw,max_linea/dw,color=Windcolor,alpha=0.3)


plot_lines()
plt.legend(fontsize=18)
plt.title('(b) PC',fontsize=32)

plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0),useMathText=True)
plt.gca().yaxis.get_offset_text().set_fontsize(18)

#plt.savefig('Oc_Tvar_vertAdvection_FC_PC_conf'+str(conf_interval)+'_residuals.png')
# Out:
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0

# %% [markdown]
# # Plot on same y-axis

# %%
vtext_loc = -1.2e-5 # For vertical line labeling
ymin = 0
ymax = 0
n_std = np.sqrt(7)
conf_interval = 95

avg_percents=np.array((.12,.2,.5,.5,38.68,60))
avg_nums=np.array((1,3,9,15,21,51))

plt.figure(figsize=(18,20))
plt.subplot(211)

avgdT,avgdT_w,min_lineT,max_lineT,bin_length = confidence_envelope(conf_interval,w,(Tde_avg),(Tde_std),n_std,avg_nums,avg_percents)
plt.semilogx(avgdT_w[1:],avgdT[1:]/dw,color='k',label='Diffusion')
plt.fill_between(avgdT_w,min_lineT/dw,max_lineT/dw,color='k',alpha=0.3)

avgds,avgds_w,min_lines,max_lines,bin_length = confidence_envelope(conf_interval,w,sum_avg,sum_std,n_std,avg_nums,avg_percents)
plt.semilogx(avgds_w[1:],avgds[1:]/dw,color='grey',label='Residual')
plt.fill_between(avgds_w,min_lines/dw,max_lines/dw,color='grey',alpha=0.3)

avgd1,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,(Had_avg),(Had_std),n_std,avg_nums,avg_percents)
plt.semilogx(avgd1_w[1:],avgd1[1:]/dw,color=KEcolor,label='Horizontal advection')
plt.fill_between(avgd1_w,min_line1/dw,max_line1/dw,color=KEcolor,alpha=0.3)

avgd2,avgd2_w,min_line2,max_line2,bin_length = confidence_envelope(conf_interval,w,(Fme_avg),(vrt_std),n_std,avg_nums,avg_percents)
plt.semilogx(avgd2_w[1:],avgd2[1:]/dw,color=PEcolor,label='Entrainment heat flux')
plt.fill_between(avgd2_w,min_line2/dw,max_line2/dw,color=PEcolor,alpha=0.3)

avgd2,avgd2_w,min_line2,max_line2,bin_length = confidence_envelope(conf_interval,w,(vta_avg),(vta_std),n_std,avg_nums,avg_percents)
plt.semilogx(avgd2_w[1:],avgd2[1:]/dw,color='c',label='Vertical advection')
plt.fill_between(avgd2_w,min_line2/dw,max_line2/dw,color='c',alpha=0.3)

avgdo,avgdo_w,min_lineo,max_lineo,bin_length = confidence_envelope(conf_interval,w,slh_avg,slh_std,n_std,avg_nums,avg_percents)
plt.semilogx(avgdo_w[1:],avgdo[1:]/dw,color=Buoycolor,label='Sensible/latent heat')
plt.fill_between(avgdo_w,min_lineo/dw,max_lineo/dw,color=Buoycolor,alpha=0.3)

avgda,avgda_w,min_linea,max_linea,bin_length = confidence_envelope(conf_interval,w,rah_avg,rah_std,n_std,avg_nums,avg_percents)
plt.semilogx(avgda_w[1:],avgda[1:]/dw,color=Windcolor,label='Radiative heat')
plt.fill_between(avgda_w,min_linea/dw,max_linea/dw,color=Windcolor,alpha=0.3)

plot_lines()
#plt.axvline(avgds_w[14])
plt.legend(fontsize=18)
plt.title('(a) FC',fontsize=32)
plt.xlabel('')

plt.ylim(-1.65e-5,1.85e-5)

plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0),useMathText=True)
plt.gca().yaxis.get_offset_text().set_fontsize(18)

plt.subplot(212)

vtext_loc = -1.6e-5 # For vertical line labeling

avgdT,avgdT_w,min_lineT,max_lineT,bin_length = confidence_envelope(conf_interval,w,(Tde_avgy),(Tde_stdy),n_std,avg_nums,avg_percents)
plt.semilogx(avgdT_w[1:],avgdT[1:]/dw,color='k',label='Diffusion')
plt.fill_between(avgdT_w,min_lineT/dw,max_lineT/dw,color='k',alpha=0.3)

avgds,avgds_w,min_lines,max_lines,bin_length = confidence_envelope(conf_interval,w,sum_avgy,sum_stdy,n_std,avg_nums,avg_percents)
plt.semilogx(avgds_w[1:],avgds[1:]/dw,color='grey',label='Residual')
plt.fill_between(avgds_w,min_lines/dw,max_lines/dw,color='grey',alpha=0.3)

avgd1,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,(Had_avgy),(Had_stdy),n_std,avg_nums,avg_percents)
plt.semilogx(avgd1_w[1:],avgd1[1:]/dw,color=KEcolor,label='Horizontal advection')
plt.fill_between(avgd1_w,min_line1/dw,max_line1/dw,color=KEcolor,alpha=0.3)

avgd2,avgd2_w,min_line2,max_line2,bin_length = confidence_envelope(conf_interval,w,(Fme_avgy),(Fme_stdy),n_std,avg_nums,avg_percents)
plt.semilogx(avgd2_w[1:],avgd2[1:]/dw,color=PEcolor,label='Entrainment heat flux')
plt.fill_between(avgd2_w,min_line2/dw,max_line2/dw,color=PEcolor,alpha=0.3)

avgd2,avgd2_w,min_line2,max_line2,bin_length = confidence_envelope(conf_interval,w,(vta_avgy),(vta_stdy),n_std,avg_nums,avg_percents)
plt.semilogx(avgd2_w[1:],avgd2[1:]/dw,color='c',label='Vertical advection')
plt.fill_between(avgd2_w,min_line2/dw,max_line2/dw,color='c',alpha=0.3)

avgdo,avgdo_w,min_lineo,max_lineo,bin_length = confidence_envelope(conf_interval,w,slh_avgy,slh_stdy,n_std,avg_nums,avg_percents)
plt.semilogx(avgdo_w[1:],avgdo[1:]/dw,color=Buoycolor,label='Sensible/latent heat')
plt.fill_between(avgdo_w,min_lineo/dw,max_lineo/dw,color=Buoycolor,alpha=0.3)

avgda,avgda_w,min_linea,max_linea,bin_length = confidence_envelope(conf_interval,w,rah_avgy,rah_stdy,n_std,avg_nums,avg_percents)
plt.semilogx(avgda_w[1:],avgda[1:]/dw,color=Windcolor,label='Radiative heat')
plt.fill_between(avgda_w,min_linea/dw,max_linea/dw,color=Windcolor,alpha=0.3)


plot_lines()
plt.legend(fontsize=18)
plt.title('(b) PC',fontsize=32)

plt.ylim(-1.65e-5,1.85e-5)

plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0),useMathText=True)
plt.gca().yaxis.get_offset_text().set_fontsize(18)

#plt.savefig('Oc_Tvar_vertAdvection_FC_PC_conf'+str(conf_interval)+'_residuals_paperRevision2.png')
# Out:
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0

# %% [markdown]
# # F-test on entrainment heat flux terms between FC and PC

# %%
import scipy.stats as sps

# %%
# FC ocean
avgd1,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,Fme_1,Fme_std,n_std,avg_nums,avg_percents)
avgd2,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,Fme_2,Fme_std,n_std,avg_nums,avg_percents)
avgd3,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,Fme_3,Fme_std,n_std,avg_nums,avg_percents)
avgd4,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,Fme_4,Fme_std,n_std,avg_nums,avg_percents)
avgd5,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,Fme_5,Fme_std,n_std,avg_nums,avg_percents)
avgd6,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,Fme_6,Fme_std,n_std,avg_nums,avg_percents)
avgd7,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,Fme_7,Fme_std,n_std,avg_nums,avg_percents)

# PC ocean
avgd1_YPC,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,Fme_1y,Fme_std,n_std,avg_nums,avg_percents)
avgd2_YPC,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,Fme_2y,Fme_std,n_std,avg_nums,avg_percents)
avgd3_YPC,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,Fme_3y,Fme_std,n_std,avg_nums,avg_percents)
avgd4_YPC,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,Fme_4y,Fme_std,n_std,avg_nums,avg_percents)
avgd5_YPC,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,Fme_5y,Fme_std,n_std,avg_nums,avg_percents)
avgd6_YPC,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,Fme_6y,Fme_std,n_std,avg_nums,avg_percents)
avgd7_YPC,avgd1_w,min_line1,max_line1,bin_length = confidence_envelope(conf_interval,w,Fme_7y,Fme_std,n_std,avg_nums,avg_percents)
# Out:
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0
# one_percent =  183.0

# %%
# Initialize a matrix of F-test values and p-values
n = len(avgd1) # number of frequency points to loop through

F_tot = np.ones(n)
P_tot = np.ones(n)

for i in np.arange(n):
    Af = np.hstack((avgd1[i],avgd2[i],avgd3[i],avgd4[i],avgd5[i],avgd6[i],avgd7[i]))
    Ay = np.hstack((avgd1_YPC[i],avgd2_YPC[i],avgd3_YPC[i],avgd4_YPC[i],avgd5_YPC[i],avgd6_YPC[i],avgd7_YPC[i]))
    f,p = sps.f_oneway(Af,Ay)
    F_tot[i] = f
    P_tot[i] = p

# %%
# Plot

plt.figure(figsize=(12,10))
plt.subplot(211)

avgd2,avgd2_w,min_line2,max_line2,bin_length = confidence_envelope(conf_interval,w,(Fme_avg),(vrt_std),n_std,avg_nums,avg_percents)
plt.semilogx(avgd2_w[1:],avgd2[1:]/dw,color=PEcolor,label='FC')
plt.fill_between(avgd2_w,min_line2/dw,max_line2/dw,color=PEcolor,alpha=0.3)

avgd2,avgd2_w,min_line2,max_line2,bin_length = confidence_envelope(conf_interval,w,(Fme_avgy),(Fme_stdy),n_std,avg_nums,avg_percents)
plt.semilogx(avgd2_w[1:],avgd2[1:]/dw,color=KEcolor,label='PC')
plt.fill_between(avgd2_w,min_line2/dw,max_line2/dw,color=KEcolor,alpha=0.3)

plot_lines()
plt.legend(fontsize=18)
plt.title('Entrainment heat flux',fontsize=32)
plt.xlabel('')
plt.axvline(avgd1_w[16],color='g')
plt.axvline(avgd1_w[34],color='g')

plt.ticklabel_format(axis='y',style='sci',scilimits=(0,0),useMathText=True)
plt.gca().yaxis.get_offset_text().set_fontsize(18)


plt.subplot(212)
plt.semilogx(avgd1_w[1:],P_tot[1:])
plt.axhline(0.1,color='r')
plt.axvline(avgd1_w[16],color='g')
plt.axvline(avgd1_w[34],color='g')
plot_lines()
plt.title('')
# Out:
# No handles with labels found to put in legend.
# one_percent =  183.0
# one_percent =  183.0
# Text(0.5, 1.0, '')
